# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\gurudutt\anaconda3\envs\perfect\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\gurudutt\anaconda3\envs\perfect\lib\site-packages (from pandas) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gurudutt\anaconda3\envs\perfect\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gurudutt\anaconda3\envs\perfect\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gurudutt\anaconda3\envs\perfect\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\gurudutt\anaconda3\envs\perfect\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# Load a CSV file
df = pd.read_csv('Market_Basket_Optimisation (1).csv')

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#            shrimp    almonds     avocado    vegetables mix green grapes  \
# 0         burgers  meatballs        eggs               NaN          NaN
# 1         chutney        NaN         NaN               NaN          NaN
# 2          turkey    avocado         NaN               NaN          NaN
# 3   mineral water       milk  energy bar  whole wheat rice    green tea
# 4  low fat yogurt        NaN         NaN               NaN          NaN
#
#   whole weat flour yams cottage cheese energy drink tomato juice  \
# 0              NaN  NaN            NaN          NaN          NaN
# 1              NaN  NaN            NaN          NaN          NaN
# 2              NaN  NaN            NaN          NaN          NaN
# 3              NaN  NaN            NaN          NaN          NaN
# 4              NaN  NaN            NaN          NaN          NaN
#
#   low fat yogurt green tea honey salad mineral water salmon antioxydant juice  \
# 0            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 1            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 2            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 3            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 4            NaN       NaN   NaN   NaN           NaN    NaN               NaN
#
#   frozen smoothie spinach  olive oil
# 0             NaN     NaN        NaN
# 1             NaN     NaN        NaN
# 2             NaN     NaN        NaN
# 3             NaN     NaN        NaN
# 4             NaN     NaN        NaN

# %%
# !pip install seaborn
from apyori import apriori
import numpy as np
import pandas as pd
import seaborn as sns

results = apriori(lst, min_support = 0.003,min_confidence = 0.4, min_value=4,min_length=2)
results= list(results)
print(results)
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\gurudutt\anaconda3\envs\perfect\lib\site-packages (from seaborn) (2.2.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\gurudutt\anaconda3\envs\perfect\lib\site-packages (from seaborn) (2.2.3)
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn)
#   Using cached matplotlib-3.10.3-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached contourpy-1.3.2-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached fonttools-4.57.0-cp313-cp313-win_amd64.whl.metadata (104 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached kiwisolver-1.4.8-cp313-cp313-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\gurudutt\anaconda3\envs\perfect\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Collecting pillow>=8 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached pillow-11.2.1-cp313-cp313-win_amd64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gurudutt\anaconda3\envs\perfect\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gurudutt\anaconda3\envs\perfect\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gurudutt\anaconda3\envs\perfect\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\gurudutt\anaconda3\envs\perfect\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached matplotlib-3.10.3-cp313-cp313-win_amd64.whl (8.1 MB)
# Using cached contourpy-1.3.2-cp313-cp313-win_amd64.whl (223 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.57.0-cp313-cp313-win_amd64.whl (2.2 MB)
# Using cached kiwisolver-1.4.8-cp313-cp313-win_amd64.whl (71 kB)
# Using cached pillow-11.2.1-cp313-cp313-win_amd64.whl (2.7 MB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.57.0 kiwisolver-1.4.8 matplotlib-3.10.3 pillow-11.2.1 pyparsing-3.2.3 seaborn-0.13.2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 7
#       4 import pandas as pd
#       5 import seaborn as sns
# ----> 7 results = apriori(lst, min_support = 0.003,min_confidence = 0.4, min_value=4,min_length=2)
#       8 results= list(results)
#       9 print(results)
#
# NameError: name 'lst' is not defined

# %%
import pandas as pd
from apyori import apriori
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# Loadimport pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

df = pd.read_csv('Market_Basket_Optimisation_1.csv')

# Convert product strings to list
df['products'] = df['products'].apply(lambda x: x.split(','))

# Transaction encoding
te = TransactionEncoder()
te_ary = te.fit(df['products']).transform(df['products'])
df_trans = pd.DataFrame(te_ary, columns=te.columns_)

# Frequent itemsets using Apriori
frequent_itemsets = apriori(df_trans, min_support=0.2, use_colnames=True)

# Generate association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0)

# Sort rules by confidence
rules = rules.sort_values(by='confidence', ascending=False)

# Display top rules
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].head())
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, support, confidence, lift]
# Index: []

# %%
import pandas as pd
from apyori import apriori
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# Load dataset
df = pd.read_csv('Market_Basket_Optimisation_1.csv')


df['products'] = df['products'].apply(lambda x: x.split(','))

te = TransactionEncoder()
te_ary = te.fit(df['products']).transform(df['products'])
df_trans = pd.DataFrame(te_ary, columns=te.columns_)

# Frequent itemsets using Apriori
frequent_itemsets = apriori(df_trans, min_support=0.002, use_colnames=True)

# Generate association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0)

# Sort rules by confidence
rules = rules.sort_values(by='confidence', ascending=False)

# Display top rules
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].head())

rules.nlargest(n=50,columns='lift')
# Out:
#                                     antecedents      consequents   support  \
# 6082              (pasta, mushroom cream sauce)       (escalope)  0.002533
# 10846  (tomatoes, olive oil, frozen vegetables)      (spaghetti)  0.002133
# 11254               (pancakes, soup, spaghetti)  (mineral water)  0.002267
# 10681           (frozen vegetables, soup, milk)  (mineral water)  0.003067
# 10723         (frozen vegetables, turkey, milk)  (mineral water)  0.002000
#
#        confidence       lift
# 6082     0.950000  11.974790
# 10846    0.842105   4.835980
# 11254    0.772727   3.241306
# 10681    0.766667   3.215884
# 10723    0.750000   3.145973
#                                            antecedents  \
# 6085                                           (pasta)
# 6080                  (escalope, mushroom cream sauce)
# 6081                                 (escalope, pasta)
# 6084                            (mushroom cream sauce)
# 6083                                        (escalope)
# 6082                     (pasta, mushroom cream sauce)
# 10850                            (tomatoes, olive oil)
# 10855                   (frozen vegetables, spaghetti)
# 11285    (chocolate, frozen vegetables, mineral water)
# 11304                              (milk, ground beef)
# 11290                   (chocolate, milk, ground beef)
# 11299               (mineral water, frozen vegetables)
# 10853                   (olive oil, frozen vegetables)
# 10852                            (tomatoes, spaghetti)
# 1910                                           (pasta)
# 1911                            (mushroom cream sauce)
# 11288                 (chocolate, milk, mineral water)
# 11301                 (frozen vegetables, ground beef)
# 10685                        (frozen vegetables, soup)
# 10684                            (mineral water, milk)
# 1202                                      (fresh tuna)
# 1203                                   (fromage blanc)
# 11294               (mineral water, milk, ground beef)
# 11295                   (chocolate, frozen vegetables)
# 11291         (mineral water, milk, frozen vegetables)
# 11298                         (chocolate, ground beef)
# 9309                                 (milk, spaghetti)
# 9304                              (chicken, olive oil)
# 11300                        (milk, frozen vegetables)
# 11289          (chocolate, ground beef, mineral water)
# 10627                            (shrimp, ground beef)
# 10630                   (frozen vegetables, spaghetti)
# 11287      (chocolate, frozen vegetables, ground beef)
# 11302                            (mineral water, milk)
# 7192                       (tomatoes, parmesan cheese)
# 7197                               (frozen vegetables)
# 9307                                 (olive oil, milk)
# 9306                              (chicken, spaghetti)
# 11292  (mineral water, frozen vegetables, ground beef)
# 11297                                (chocolate, milk)
# 3913                                     (light cream)
# 3908                          (mineral water, chicken)
# 10626                 (frozen vegetables, ground beef)
# 10631                              (shrimp, spaghetti)
# 7196                                 (parmesan cheese)
# 7193                     (tomatoes, frozen vegetables)
# 11293           (milk, frozen vegetables, ground beef)
# 11296                       (chocolate, mineral water)
# 6009                          (escalope, french fries)
# 6012                            (mushroom cream sauce)
#
#                                            consequents  antecedent support  \
# 6085                  (escalope, mushroom cream sauce)            0.015733
# 6080                                           (pasta)            0.005733
# 6081                            (mushroom cream sauce)            0.005867
# 6084                                 (escalope, pasta)            0.019067
# 6083                     (pasta, mushroom cream sauce)            0.079333
# 6082                                        (escalope)            0.002667
# 10850                   (frozen vegetables, spaghetti)            0.007200
# 10855                            (tomatoes, olive oil)            0.027867
# 11285                              (milk, ground beef)            0.009733
# 11304    (chocolate, frozen vegetables, mineral water)            0.022000
# 11290               (mineral water, frozen vegetables)            0.006133
# 11299                   (chocolate, milk, ground beef)            0.035733
# 10853                            (tomatoes, spaghetti)            0.011333
# 10852                   (olive oil, frozen vegetables)            0.020933
# 1910                            (mushroom cream sauce)            0.015733
# 1911                                           (pasta)            0.019067
# 11288                 (frozen vegetables, ground beef)            0.014000
# 11301                 (chocolate, milk, mineral water)            0.016933
# 10685                            (mineral water, milk)            0.008000
# 10684                        (frozen vegetables, soup)            0.048000
# 1202                                   (fromage blanc)            0.022267
# 1203                                      (fresh tuna)            0.013600
# 11294                   (chocolate, frozen vegetables)            0.011067
# 11295               (mineral water, milk, ground beef)            0.022933
# 11291                         (chocolate, ground beef)            0.011067
# 11298         (mineral water, milk, frozen vegetables)            0.023067
# 9309                              (chicken, olive oil)            0.035467
# 9304                                 (milk, spaghetti)            0.007200
# 11300          (chocolate, ground beef, mineral water)            0.023600
# 11289                        (milk, frozen vegetables)            0.010933
# 10627                   (frozen vegetables, spaghetti)            0.011467
# 10630                            (shrimp, ground beef)            0.027867
# 11287                            (mineral water, milk)            0.005733
# 11302      (chocolate, frozen vegetables, ground beef)            0.048000
# 7192                               (frozen vegetables)            0.003200
# 7197                       (tomatoes, parmesan cheese)            0.095333
# 9307                              (chicken, spaghetti)            0.017067
# 9306                                 (olive oil, milk)            0.017200
# 11292                                (chocolate, milk)            0.009200
# 11297  (mineral water, frozen vegetables, ground beef)            0.032133
# 3913                          (mineral water, chicken)            0.015600
# 3908                                     (light cream)            0.022800
# 10626                              (shrimp, spaghetti)            0.016933
# 10631                 (frozen vegetables, ground beef)            0.021200
# 7196                     (tomatoes, frozen vegetables)            0.019867
# 7193                                 (parmesan cheese)            0.016133
# 11293                       (chocolate, mineral water)            0.005733
# 11296           (milk, frozen vegetables, ground beef)            0.052667
